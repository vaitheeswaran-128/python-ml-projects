# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

df=pd.read_csv("C:/Users/USER/OneDrive/Desktop/AirBNB-1.csv")
df
# Out:
#              id        room_type  accommodates  bathrooms cancellation_policy  \
# 0       6901257  Entire home/apt           3.0        1.0              strict
# 1       6304928  Entire home/apt           7.0        1.0              strict
# 2       7919400  Entire home/apt           5.0        1.0            moderate
# 3      13418779  Entire home/apt           4.0        1.0            flexible
# 4       3808709  Entire home/apt           2.0        1.0            moderate
# ...         ...              ...           ...        ...                 ...
# 60204   9304836  Entire home/apt           6.0        2.5            flexible
# 60205  17422489     Private room           2.0        1.0              strict
# 60206   6357564  Entire home/apt           2.0        1.0            moderate
# 60207  12957659  Entire home/apt           6.0        2.0              strict
# 60208  11626869  Entire home/apt           3.0        1.0            flexible
#
# ...

# %%
df.head()
# Out:
#          id        room_type  accommodates  bathrooms cancellation_policy  \
# 0   6901257  Entire home/apt           3.0        1.0              strict
# 1   6304928  Entire home/apt           7.0        1.0              strict
# 2   7919400  Entire home/apt           5.0        1.0            moderate
# 3  13418779  Entire home/apt           4.0        1.0            flexible
# 4   3808709  Entire home/apt           2.0        1.0            moderate
#
#   cleaning_fee instant_bookable  review_scores_rating  bedrooms  beds  \
# 0         True                f                 100.0       1.0   1.0
# 1         True                t                  93.0       3.0   3.0
# 2         True                t                  92.0       1.0   3.0
# 3         True                f                   NaN       2.0   2.0
# 4         True                t                  40.0       0.0   1.0
#
#    log_price
# 0   5.010635
# 1   5.129899
# 2   4.976734
# 3   6.620073
# 4   4.744932

# %%
df.tail()
# Out:
#              id        room_type  accommodates  bathrooms cancellation_policy  \
# 60204   9304836  Entire home/apt           6.0        2.5            flexible
# 60205  17422489     Private room           2.0        1.0              strict
# 60206   6357564  Entire home/apt           2.0        1.0            moderate
# 60207  12957659  Entire home/apt           6.0        2.0              strict
# 60208  11626869  Entire home/apt           3.0        1.0            flexible
#
#       cleaning_fee instant_bookable  review_scores_rating  bedrooms  beds  \
# 60204         True                f                 100.0       3.0   3.0
# 60205         True                t                  95.0       1.0   1.0
# 60206        False                f                 100.0       0.0   1.0
# 60207         True                f                  94.0       3.0   3.0
# 60208         True                f                 100.0       1.0   1.0
#
#        log_price
# 60204   6.437752
# ...

# %%
df.shape
# Out:
# (60209, 11)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60209 entries, 0 to 60208
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    60209 non-null  int64
#  1   room_type             60204 non-null  object
#  2   accommodates          60206 non-null  float64
#  3   bathrooms             60042 non-null  float64
#  4   cancellation_policy   60201 non-null  object
#  5   cleaning_fee          60205 non-null  object
#  6   instant_bookable      60209 non-null  object
#  7   review_scores_rating  46608 non-null  float64
#  8   bedrooms              60128 non-null  float64
#  9   beds                  60099 non-null  float64
#  10  log_price             60209 non-null  float64
# dtypes: float64(6), int64(1), object(4)
# memory usage: 5.1+ MB

# %%
df.describe().T
# Out:
#                         count          mean           std    min  \
# id                    60209.0  1.127395e+07  6.080397e+06  344.0
# accommodates          60206.0  3.153623e+00  2.156921e+00    1.0
# bathrooms             60042.0  1.235935e+00  5.834137e-01    0.0
# review_scores_rating  46608.0  9.408765e+01  7.814210e+00   20.0
# bedrooms              60128.0  1.266415e+00  8.525744e-01    0.0
# beds                  60099.0  1.711426e+00  1.260071e+00    0.0
# log_price             60209.0  4.781945e+00  7.173180e-01    0.0
#
#                                25%           50%           75%           max
# id                    6.278513e+06  1.226280e+07  1.640707e+07  2.123090e+07
# accommodates          2.000000e+00  2.000000e+00  4.000000e+00  1.600000e+01
# bathrooms             1.000000e+00  1.000000e+00  1.000000e+00  8.000000e+00
# review_scores_rating  9.200000e+01  9.600000e+01  1.000000e+02  1.000000e+02
# ...

# %%
df.describe(include="all")
# Out:
#                   id        room_type  accommodates     bathrooms  \
# count   6.020900e+04            60204  60206.000000  60042.000000
# unique           NaN                3           NaN           NaN
# top              NaN  Entire home/apt           NaN           NaN
# freq             NaN            33554           NaN           NaN
# mean    1.127395e+07              NaN      3.153623      1.235935
# std     6.080397e+06              NaN      2.156921      0.583414
# min     3.440000e+02              NaN      1.000000      0.000000
# 25%     6.278513e+06              NaN      2.000000      1.000000
# 50%     1.226280e+07              NaN      2.000000      1.000000
# 75%     1.640707e+07              NaN      4.000000      1.000000
# max     2.123090e+07              NaN     16.000000      8.000000
#
#        cancellation_policy cleaning_fee instant_bookable  \
# count                60201        60205            60209
# ...

# %%
df.dtypes
# Out:
# id                        int64
# room_type                object
# accommodates            float64
# bathrooms               float64
# cancellation_policy      object
# cleaning_fee             object
# instant_bookable         object
# review_scores_rating    float64
# bedrooms                float64
# beds                    float64
# log_price               float64
# dtype: object

# %%
df.isnull()
# Out:
#           id  room_type  accommodates  bathrooms  cancellation_policy  \
# 0      False      False         False      False                False
# 1      False      False         False      False                False
# 2      False      False         False      False                False
# 3      False      False         False      False                False
# 4      False      False         False      False                False
# ...      ...        ...           ...        ...                  ...
# 60204  False      False         False      False                False
# 60205  False      False         False      False                False
# 60206  False      False         False      False                False
# 60207  False      False         False      False                False
# 60208  False      False         False      False                False
#
#        cleaning_fee  instant_bookable  review_scores_rating  bedrooms   beds  \
# ...

# %%
df.isnull().sum()
# Out:
# id                          0
# room_type                   5
# accommodates                3
# bathrooms                 167
# cancellation_policy         8
# cleaning_fee                4
# instant_bookable            0
# review_scores_rating    13601
# bedrooms                   81
# beds                      110
# log_price                   0
# dtype: int64

# %%
df.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 60204    False
# 60205    False
# 60206    False
# 60207    False
# 60208    False
# Length: 60209, dtype: bool

# %%
df['room_type'].unique()
# Out:
# array(['Entire home/apt', 'Private room', 'Shared room', nan],
#       dtype=object)

# %%
df["cancellation_policy"].unique()
# Out:
# array(['strict', 'moderate', 'flexible', nan], dtype=object)

# %%
df['cleaning_fee'].unique()
# Out:
# array([True, False, nan], dtype=object)

# %%
df["accommodates"].value_counts()
# Out:
# accommodates
# 2.0     25901
# 4.0      9834
# 1.0      7695
# 3.0      6286
# 6.0      4020
# 5.0      2769
# 8.0      1452
# 7.0       772
# 10.0      563
# 16.0      243
# 9.0       224
# 12.0      218
# 14.0       90
# 11.0       62
# 15.0       49
# 13.0       28
# Name: count, dtype: int64

# %% [markdown]
# ## UNIVARIATE

# %%
plt.hist(df['accommodates'])

plt.savefig("histogram.png",format="png")
plt.show()

# %%
sns.countplot(data=df,x="room_type",palette=["red","blue","green"])
plt.savefig("barchart.png",format="png")
plt.show()
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_8232\663873738.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df,x="room_type",palette=["red","blue","green"])

# %% [markdown]
# # BIVARIATE

# %%
grouped = df.groupby("cancellation_policy").size().reset_index(name="counts")

plt.figure(figsize=(8, 8))

explode = [0.1] * len(grouped)
plt.pie(
    grouped["counts"],                     
    labels=grouped["cancellation_policy"],   
    autopct='%1.1f%%',                       
    startangle=140,                         
    explode=explode,                        
    colors=sns.color_palette("pastel")       
)

plt.title("Count of Cancellation Policy Types", fontsize=16)
plt.savefig("piechart.png",format="png")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

room_accommodates = df.groupby("room_type")["accommodates"].sum().reset_index()

plt.figure(figsize=(8, 6))
sns.barplot(data=room_accommodates, x="room_type", y="accommodates", palette="pastel")

ax = plt.gca()

for bar in ax.patches:
    x = bar.get_x() + bar.get_width() / 2  
    y = bar.get_height()  
    ax.text(x, y, f'{y:.0f}', ha='center', va='bottom', fontsize=10)

plt.xticks(rotation=45)
plt.title("Total Accommodates per Room Type")
plt.xlabel("Room Type")
plt.ylabel("Total Accommodates")
plt.savefig("barchart_2.png",format="png")
plt.show()
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_8232\2333668396.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=room_accommodates, x="room_type", y="accommodates", palette="pastel")

# %%
plt.figure(figsize=(8, 6))

for room_type, group in df.groupby("room_type"):
    sns.kdeplot(data=group, x="accommodates", fill=True, label=room_type)

plt.title("KDE Plot of Accommodates by Room Type", fontsize=14)
plt.xlabel("Number of People Accommodated", fontsize=12)
plt.ylabel("Density", fontsize=12)
plt.legend(title="Room Type")

plt.savefig("KDEplot.png",format="png")

plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(8, 6))
sns.violinplot(data=df, x="room_type", y="review_scores_rating", palette="muted", inner="quartile")
plt.title("Room Type-wise Review Ratings (Violin Plot)")
plt.xlabel("Room Type")
plt.ylabel("Review Scores Rating")
plt.xticks(rotation=45)
plt.savefig("violinplot.png",format="png")
plt.show()
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_8232\3338715474.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(data=df, x="room_type", y="review_scores_rating", palette="muted", inner="quartile")
